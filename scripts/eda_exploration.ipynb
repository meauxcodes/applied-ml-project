# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

clean_data = pd.read_csv("../data/clean/cleaned_garmin_data.csv")


corr_pairs = clean_data.corr(numeric_only=True).unstack()
corr_pairs = corr_pairs[corr_pairs.index.get_level_values(0) != corr_pairs.index.get_level_values(1)]
corr_pairs_sorted = corr_pairs.reindex(corr_pairs.abs().sort_values(ascending=False).index).to_string()
print(corr_pairs_sorted)
# Out:
# resting heart rate (overnight)   resting heart rate                 1.000000e+00
# resting heart rate               resting heart rate (overnight)     1.000000e+00
# avg overnight HRV                hrv last night avg                 1.000000e+00
# avg sleep respiration            avg respiration (sleep)            1.000000e+00
# avg respiration (sleep)          avg sleep respiration              1.000000e+00
# hrv last night avg               avg overnight HRV                  1.000000e+00
# total calories                   active calories                    9.902113e-01
# active calories                  total calories                     9.902113e-01
# sleep total seconds              light sleep seconds                9.657349e-01
# light sleep seconds              sleep total seconds                9.657349e-01
# rem sleep percent                rem sleep seconds                  9.526091e-01
# rem sleep seconds                rem sleep percent                  9.526091e-01
# ...

# %% [markdown]
# After reviewing the sorted list of correlated features, the following features will be kept for a correlation heat map:
# "avg overnight HRV"
# "overall sleep score"
# "avg sleep stress"
# "resting heart rate"
# "total steps"
# "avg sleep respiration"
# "body battery charged"
# "max heart rate"
# "deep sleep percent"
# "moderate intensity minutes"
# "min heart rate"
# "awake count"
